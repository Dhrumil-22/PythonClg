# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pprint

# %%
url=f"https://jsonplaceholder.typicode.com/posts"
response=requests.get(url)
print(response.json())


import requests
params={'userId':1}
url='https://jsonplaceholder.typicode.com/posts'
response=requests.get(url,params=params)
print(response.json())
# Out:
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit'}, {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'body': 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque'}, {'userId': 1, 'id': 6, 'title': 'dolorem eum magni eos aperiam quia', 'body': 'ut aspernatur corporis harum nihil quis provident sequi\nmollitia nobis aliquid molestiae\nperspiciatis et ea nemo ab reprehenderit accusantium quas\nvoluptate dolores velit et doloremque molestiae'}, {'userId': 1, 'id': 7, 'title': 'magnam facilis autem', 'body': 'dolore placeat quibusdam ea quo vitae\nmagni quis enim qui quis quo nemo aut saepe\nquidem repellat excepturi ut quia\nsunt ut sequi eos ea sed quas'}, {'userId': 1, 'id': 8, 'title': 'dolorem dolore est ipsam', 'body': 'dignissimos aperiam dolorem qui eum\nfacilis quibusdam animi sint suscipit qui sint possimus cum\nquaerat magni maiores excepturi\nipsam ut commodi dolor voluptatum modi aut vitae'}, {'userId': 1, 'id': 9, 'title': 'nesciunt iure omnis dolorem tempora et accusantium', 'body': 'consectetur animi nesciunt iure dolore\nenim quia ad\nveniam autem ut quam aut nobis\net est aut quod aut provident voluptas autem voluptas'}, {'userId': 1, 'id': 10, 'title': 'optio molestias id quia eum', 'body': 'quo et expedita modi cum officia vel magni\ndoloribus qui repudiandae\nvero nisi sit\nquos veniam quod sed accusamus veritatis error'}, {'userId': 2, 'id': 11, 'title': 'et ea vero quia laudantium autem', 'body': 'delectus reiciendis molestiae occaecati non minima eveniet qui voluptatibus\naccusamus in eum beatae sit\nvel qui neque voluptates ut commodi qui incidunt\nut animi commodi'}, {'userId': 2, 'id': 12, 'title': 'in quibusdam tempore odit est dolorem', 'body': 'itaque id aut magnam\npraesentium quia et ea odit et ea voluptas et\nsapiente quia nihil amet occaecati quia id voluptatem\nincidunt ea est distinctio odio'}, {'userId': 2, 'id': 13, 'title': 'dolorum ut in voluptas mollitia et saepe quo animi', 'body': 'aut dicta possimus sint mollitia voluptas commodi quo doloremque\niste corrupti reiciendis voluptatem eius rerum\nsit cumque quod eligendi laborum minima\nperferendis recusandae assumenda consectetur porro architecto ipsum ipsam'}, {'userId': 2, 'id': 14, 'title': 'voluptatem eligendi optio', 'body': 'fuga et accusamus dolorum perferendis illo voluptas\nnon doloremque neque facere\nad qui dolorum molestiae beatae\nsed aut voluptas totam sit illum'}, {'userId': 2, 'id': 15, 'title': 'eveniet quod temporibus', 'body': 'reprehenderit quos placeat\nvelit minima officia dolores impedit repudiandae molestiae nam\nvoluptas recusandae quis delectus\nofficiis harum fugiat vitae'}, {'userId': 2, 'id': 16, 'title': 'sint suscipit perspiciatis velit dolorum rerum ipsa laboriosam odio', 'body': 'suscipit nam nisi quo aperiam aut\nasperiores eos fugit maiores voluptatibus quia\nvoluptatem quis ullam qui  ...
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit'}, {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'body': 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque'}, {'userId': 1, 'id': 6, 'title': 'dolorem eum magni eos aperiam quia', 'body': 'ut aspernatur corporis harum nihil quis provident sequi\nmollitia nobis aliquid molestiae\nperspiciatis et ea nemo ab reprehenderit accusantium quas\nvoluptate dolores velit et doloremque molestiae'}, {'userId': 1, 'id': 7, 'title': 'magnam facilis autem', 'body': 'dolore placeat quibusdam ea quo vitae\nmagni quis enim qui quis quo nemo aut saepe\nquidem repellat excepturi ut quia\nsunt ut sequi eos ea sed quas'}, {'userId': 1, 'id': 8, 'title': 'dolorem dolore est ipsam', 'body': 'dignissimos aperiam dolorem qui eum\nfacilis quibusdam animi sint suscipit qui sint possimus cum\nquaerat magni maiores excepturi\nipsam ut commodi dolor voluptatum modi aut vitae'}, {'userId': 1, 'id': 9, 'title': 'nesciunt iure omnis dolorem tempora et accusantium', 'body': 'consectetur animi nesciunt iure dolore\nenim quia ad\nveniam autem ut quam aut nobis\net est aut quod aut provident voluptas autem voluptas'}, {'userId': 1, 'id': 10, 'title': 'optio molestias id quia eum', 'body': 'quo et expedita modi cum officia vel magni\ndoloribus qui repudiandae\nvero nisi sit\nquos veniam quod sed accusamus veritatis error'}]

# %%
headers={
    'user-Agent':'Mozilla/5.0',
    'Accept':'application/json'
}
url='https://jsonplaceholder.typicode.com/posts'
response=requests.get(url,headers=headers)
print(response.headers)
# Out:
# {'Date': 'Tue, 26 May 2026 06:17:50 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'access-control-allow-credentials': 'true', 'Cache-Control': 'max-age=43200', 'Content-Encoding': 'gzip', 'etag': 'W/"6b80-Ybsq/K6GwwqrYkAsFxqDXGC7DoM"', 'expires': '-1', 'nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'pragma': 'no-cache', 'report-to': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=0CX4uI9y64G1DQfjZxyU2FW%2BdZmLEPOpSnot%2BwYUdIQ%3D\\u0026sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d\\u0026ts=1779761448"}],"max_age":3600}', 'reporting-endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=0CX4uI9y64G1DQfjZxyU2FW%2BdZmLEPOpSnot%2BwYUdIQ%3D&sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d&ts=1779761448"', 'Server': 'cloudflare', 'vary': 'Origin, Accept-Encoding', 'via': '2.0 heroku-router', 'x-content-type-options': 'nosniff', 'x-powered-by': 'Express', 'x-ratelimit-limit': '1000', 'x-ratelimit-remaining': '999', 'x-ratelimit-reset': '1779761471', 'Age': '14822', 'cf-cache-status': 'HIT', 'CF-RAY': 'a01aa8bc39fdf890-SIN', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
new_post={
    'userid':1,
    'title':'Learning Request',
    'body':'This is tutorial content'
}
url='https://jsonplaceholder.typicode.com/posts'
response=requests.post(url,json=new_post)
print(response.status_code)
print(response.json())
# Out:
# 201
# {'userid': 1, 'title': 'Learning Request', 'body': 'This is tutorial content', 'id': 101}

# %%
updated_post={
    'id':1,
    'title':'update title',
    'body':'update body',
    'userid':1
}
url='https://jsonplaceholder.typicode.com/posts'
response=requests.post(url,json=new_post)
print(response.status_code)
print(response.json())
# Out:
# 201
# {'userid': 1, 'title': 'Learning Request', 'body': 'This is tutorial content', 'id': 101}

# %%
url='https://jsonplaceholder.typicode.com/posts/1'
response=requests.delete(url)
print(response.status_code)
print(response.json())
# Out:
# 200
# {}

# %%
url='https://jsonplaceholder.typicode.com/posts'
token = 'my_secret_token'
headers = {
    'Authorization':f'Bearer {token}'
}
response=requests.get(url,headers=headers)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# ## Pagination

# %%
url='https://jsonplaceholder.typicode.com/posts'
params = {
    '_page':1,
    '_limit':5
}
response=requests.get(url,params=params)
print(response.json())
# Out:
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit'}, {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'body': 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque'}]

# %%
page = 1
while page<=3:
    url='https://jsonplaceholder.typicode.com/posts'
    params = {
        '_page':1,
        '_limit':5
    }
    response=requests.get(url,params=params)
    print(f'page:{page}')
    print(response.json())
    page+=1
# Out:
# page:1
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit'}, {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'body': 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque'}]
# page:2
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit'}, {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'body': 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque'}]
# page:3
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit'}, {'userId': 1, 'id': 5, 'title': 'nesciunt quas odio', 'body': 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque'}]

# %%
import json
http = 'https://my-json-server.typicode.com/kavit88/apidemo/db'
response=requests.get(http)
result=response.json()
with open('demo.json','w') as f:
    json.dump(result,f,indent=4)
with open('demo.json','r') as f:
    data = json.load(f)
print(data)
# Out:
# {'DIVISION': {'0': 'A7', '1': 'A4', '2': 'A4', '3': 'A2', '4': 'A2', '5': 'A2', '6': 'A4', '7': 'A7', '8': 'A2', '9': 'A2', '10': 'A7', '11': 'A2', '12': 'A7', '13': 'A7', '14': 'A2', '15': 'A2', '16': 'A7', '17': 'A2', '18': 'A7', '19': 'A4', '20': 'A4', '21': 'A4', '22': 'A2', '23': 'A7', '24': 'A4', '25': 'A4', '26': 'A4', '27': 'A7', '28': 'A2', '29': 'A4', '30': 'A2', '31': 'A7', '32': 'A2', '33': 'A7', '34': 'A4', '35': 'A2', '36': 'A2', '37': 'A4', '38': 'A4', '39': 'A7', '40': 'A4', '41': 'A4', '42': 'A4', '43': 'A5', '44': 'A4', '45': 'A4', '46': 'A2', '47': 'A7', '48': 'A4', '49': 'A4', '50': 'A7', '51': 'A2', '52': 'A2', '53': 'A2', '54': 'A2', '55': 'A2', '56': 'A7', '57': 'A4', '58': 'A7', '59': 'A7', '60': 'A2', '61': 'A7', '62': 'A2', '63': 'A2', '64': 'A2', '65': 'A2', '66': 'A2', '67': 'A4', '68': 'A2', '69': 'A2', '70': 'A4', '71': 'A2', '72': 'A2', '73': 'A2', '74': 'A2', '75': 'A4', '76': 'A2', '77': 'A2', '78': 'A2', '79': 'A4', '80': 'A4', '81': 'A4', '82': 'A7', '83': 'A7', '84': 'A7', '85': 'A4', '86': 'A4', '87': 'A2', '88': 'A2', '89': 'A2', '90': 'A4', '91': 'A7', '92': 'A4', '93': 'A2', '94': 'A7', '95': 'A7', '96': 'A4', '97': 'A4', '98': 'A4', '99': 'A7'}, 'ROLL': {'0': 64, '1': 19, '2': 103, '3': 114, '4': 243, '5': 85, '6': 245, '7': 12, '8': 115, '9': 232, '10': 215, '11': 14, '12': 206, '13': 105, '14': 48, '15': 20, '16': 29, '17': 68, '18': 242, '19': 97, '20': 97, '21': 151, '22': 79, '23': 22, '24': 169, '25': 221, '26': 194, '27': 139, '28': 203, '29': 96, '30': 136, '31': 116, '32': 88, '33': 56, '34': 41, '35': 36, '36': 221, '37': 57, '38': 161, '39': 125, '40': 172, '41': 181, '42': 147, '43': 77, '44': 248, '45': 113, '46': 5, '47': 90, '48': 11, '49': 121, '50': 15, '51': 233, '52': 129, '53': 179, '54': 185, '55': 46, '56': 209, '57': 215, '58': 15, '59': 62, '60': 100, '61': 119, '62': 158, '63': 198, '64': 8, '65': 62, '66': 230, '67': 65, '68': 236, '69': 215, '70': 58, '71': 101, '72': 187, '73': 223, '74': 210, '75': 109, '76': 87, '77': 80, '78': 225, '79': 55, '80': 129, '81': 27, '82': 222, '83': 52, '84': 126, '85': 123, '86': 133, '87': 125, '88': 123, '89': 206, '90': 141, '91': 245, '92': 246, '93': 110, '94': 163, '95': 169, '96': 57, '97': 143, '98': 48, '99': 183}, 'NAME': {'0': 'NEHMAT BALASUBRAMANIAN', '1': 'SANA KURIAN', '2': 'AARUSH ZACHARIA', '3': 'NIRVI VENKATESH', '4': 'AARAV SACHDEVA', '5': 'OJAS BAHL', '6': 'LAKSHIT SOMAN', '7': 'NEELOFAR LALLA', '8': 'KANAV DEWAN', '9': 'DHANUSH CHOUDHARY', '10': 'ROMIL AHUJA', '11': 'ZOYA KOTA', '12': 'TRISHA LALA', '13': 'SAMAR RAU', '14': 'PRIYANSH TAILOR', '15': 'IVAN GANDHI', '16': 'AAYUSH RAU', '17': 'LAVANYA RAJAGOPAL', '18': 'RAUNAK SAWHNEY', '19': 'AMIRA MAHARAJ', '20': 'CHARVI COMAR', '21': 'BIJU KULKARNI', '22': 'ADVIK CHAUDHRY', '23': 'HUNAR KARNIK', '24': 'SEHER RASTOGI', '25': 'NIRVI BHATT', '26': 'ARADHYA TOOR', '27': 'RAGHAV APTE', '28': 'ANAYA SARAF', '29': 'MAHIKA KOTA', '30': 'ANAHI JAGGI', '31': 'NIRVI GHOSH', '32': 'NITYA GARA', '33': 'ANIKA ZACHARIAH', '34': 'LAVANYA SARKAR', '35': 'HIMMAT TOOR', '36': 'ROHAN DYAL', '37': 'ONKAR CHAUHAN', '38': 'DEVANSH DANI', '39': 'HIRAN CHAUDHARI', '40': 'ABRAM GOLE', '41': 'ADAH KAMDAR', '42': 'YUVAAN CHAUDRY', '43': 'HUNAR SRINIVAS', '44': 'AAINA KRISH', '45': 'KRISH MAGAR', '46': 'RHEA DESAI', '47': 'AYESHA SANDAL', '48': 'NIRVAAN SACHDEVA', '49': 'RITVIK SALVI', '50': 'PRERAK GERA', '51': 'IVAN VOHRA', '52': 'AAINA IYENGAR', '53': 'PARINAAZ WADHWA', '54': 'IVAN DUGAR', '55': 'ARNAV BAINS', '56': 'DHANUSH HANDA', '57': 'RENEE VOHRA', '58': 'RAGHAV UPPAL', '59': 'KIARA CHADHA', '60': 'PRISHA DUGAR', '61': 'DIVYANSH CHAKRABARTI', '62': 'ARMAAN CHAHAL', '63': 'DARSHIT KOTA', '64': 'HIRAN DHAR', '65': 'ISHITA KHALSA', '66': 'RIAAN VIRK', '67': 'VEDIKA BALI', '68': 'DHANUK MANGAL', '69': 'TEJAS DEOL', '70': 'VANYA CHANDER', '71': 'KIMAYA UPADHYAY', '72': 'MADHAV KUMAR', '73': 'PRERAK GANESH', '74': 'KIARA BHARGAVA', '75': 'MEHUL GOKHALE', '76': 'INDRANS RATTAN', '77': ...

# %%
import requests

# =====================================================
# BASE URL
# =====================================================

BASE_URL = "http://127.0.0.1:8000"

# =====================================================
# TOKEN
# =====================================================

TOKEN = "mysecret123"

# =====================================================
# COMMON PARAMS
# =====================================================

params = {
    "api_token": TOKEN
}

# =====================================================
# GET ALL STUDENTS
# =====================================================

response = requests.get(
    f"{BASE_URL}/students",
    params={
        "api_token": TOKEN,
        "skip": 0,
        "limit": 5
    }
)

print("\n==============================")
print("GET ALL STUDENTS")
print("==============================")

print(response.json())

# =====================================================
# GET SINGLE STUDENT
# =====================================================

response = requests.get(
    f"{BASE_URL}/students/1",
    params=params
)

print("\n==============================")
print("GET SINGLE STUDENT")
print("==============================")

print(response.json())

# =====================================================
# POST API
# =====================================================

new_student = {
    "id": 999,
    "name": "NEW STUDENT",
    "roll_no": 999,
    "division": "A7",
    "marks": "25"
}

response = requests.post(
    f"{BASE_URL}/students",
    json=new_student,
    params=params
)

print("\n==============================")
print("POST API")
print("==============================")

print(response.json())

# =====================================================
# CHECK DATA AFTER POST
# =====================================================

response = requests.get(
    f"{BASE_URL}/students/999",
    params=params
)

print("\n==============================")
print("CHECK AFTER POST")
print("==============================")

print(response.json())

# =====================================================
# PUT API (FULL UPDATE)
# =====================================================

updated_student = {
    "id": 999,
    "name": "UPDATED STUDENT",
    "roll_no": 500,
    "division": "A4",
    "marks": "30"
}

response = requests.put(
    f"{BASE_URL}/students/999",
    json=updated_student,
    params=params
)

print("\n==============================")
print("PUT API")
print("==============================")

print(response.json())

# =====================================================
# CHECK DATA AFTER PUT
# =====================================================

response = requests.get(
    f"{BASE_URL}/students/999",
    params=params
)

print("\n==============================")
print("CHECK AFTER PUT")
print("==============================")

print(response.json())

# =====================================================
# PATCH API (PARTIAL UPDATE)
# =====================================================

patch_data = {
    "marks": "35"
}

response = requests.patch(
    f"{BASE_URL}/students/999",
    json=patch_data,
    params=params
)

print("\n==============================")
print("PATCH API")
print("==============================")

print(response.json())

# =====================================================
# CHECK DATA AFTER PATCH
# =====================================================

response = requests.get(
    f"{BASE_URL}/students/999",
    params=params
)

print("\n==============================")
print("CHECK AFTER PATCH")
print("==============================")

print(response.json())

response = requests.get(
    f"{BASE_URL}/students/999",
    params=params
)
print(response.json())
# =====================================================
# DELETE API
# =====================================================

response = requests.delete(
    f"{BASE_URL}/students/999",
    params=params
)

print("\n==============================")
print("DELETE API")
print("==============================")

print(response.json())

# =====================================================
# CHECK AFTER DELETE
# =====================================================

response = requests.get(
    f"{BASE_URL}/students/999",
    params=params
)

print("\n==============================")
print("CHECK AFTER DELETE")
print("==============================")

print(response.json())

# =====================================================
# HEADERS API
# =====================================================

response = requests.get(
    f"{BASE_URL}/headers",
    params=params
)

print("\n==============================")
print("HEADERS API")
print("==============================")

print(response.json())

# =====================================================
# RATE LIMIT TEST
# =====================================================

print("\n==============================")
print("RATE LIMIT TEST")
print("==============================")

for i in range(12):

    response = requests.get(
        f"{BASE_URL}/students",
        params=params
    )

    print(f"Request {i+1} --> Status Code:", response.status_code)
# Out:
# ==============================
# GET ALL STUDENTS
# ==============================
# [{'id': 1, 'enrol no': 24002200000000.0, 'name': 'AAGAM DILIPBHAI SHAH', 'roll no': 137, 'marks': '20'}, {'id': 2, 'enrol no': 24002200000000.0, 'name': 'APARNATHI YAKSHGIRI HIRENGIRI', 'roll no': 229, 'marks': '15'}, {'id': 3, 'enrol no': 24002200000000.0, 'name': 'ARYA JAY BHARATBHAI', 'roll no': 227, 'marks': '11.5'}, {'id': 4, 'enrol no': 24002200000000.0, 'name': 'BHARTY MARIYA ABDUL RAFEY', 'roll no': 54, 'marks': '20.5'}, {'id': 5, 'enrol no': 24002200000000.0, 'name': 'BHUVA MEK SHIRISHBHAI', 'roll no': 240, 'marks': '11'}]
#
# ==============================
# GET SINGLE STUDENT
# ==============================
# {'id': 1, 'enrol no': 24002200000000.0, 'name': 'AAGAM DILIPBHAI SHAH', 'roll no': 137, 'marks': '20'}
#
# ==============================
# POST API
# ==============================
# {'message': 'Student added successfully', 'data': {'id': 999, 'name': 'NEW STUDENT', 'roll_no': 999, 'division': 'A7', 'marks': '25'}}
#
# ==============================
# CHECK AFTER POST
# ==============================
# {'id': 999, 'name': 'NEW STUDENT', 'roll_no': 999, 'division': 'A7', 'marks': '25'}
#
# ==============================
# PUT API
# ==============================
# {'message': 'Student updated successfully', 'data': {'id': 999, 'name': 'UPDATED STUDENT', 'roll_no': 500, 'division': 'A4', 'marks': '30'}}
#
# ==============================
# CHECK AFTER PUT
# ==============================
# {'id': 999, 'name': 'UPDATED STUDENT', 'roll_no': 500, 'division': 'A4', 'marks': '30'}
#
# ==============================
# PATCH API
# ==============================
# {'message': 'Student patched successfully', 'data': {'id': 999, 'name': 'UPDATED STUDENT', 'roll_no': 500, 'division': 'A4', 'marks': '35'}}
#
# ==============================
# CHECK AFTER PATCH
# ==============================
# {'id': 999, 'name': 'UPDATED STUDENT', 'roll_no': 500, 'division': 'A4', 'marks': '35'}
# {'id': 999, 'name': 'UPDATED STUDENT', 'roll_no': 500, 'division': 'A4', 'marks': '35'}
#
# ==============================
# DELETE API
# ==============================
# {'message': 'Student deleted successfully'}
#
# ==============================
# CHECK AFTER DELETE
# ==============================
# {'error': 'Student not found'}
#
# ==============================
# HEADERS API
# ==============================
# {'headers': {'host': '127.0.0.1:8000', 'user-agent': 'python-requests/2.32.3', 'accept-encoding': 'gzip, deflate, br, zstd', 'accept': '*/*', 'connection': 'keep-alive'}}
#
# ==============================
# RATE LIMIT TEST
# ==============================
# Request 1 --> Status Code: 200
# Request 2 --> Status Code: 200
# Request 3 --> Status Code: 200
# Request 4 --> Status Code: 200
# Request 5 --> Status Code: 200
# Request 6 --> Status Code: 200
# Request 7 --> Status Code: 200
# Request 8 --> Status Code: 200
# Request 9 --> Status Code: 200
# Request 10 --> Status Code: 429
# Request 11 --> Status Code: 429
# Request 12 --> Status Code: 429
