# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df =pd.read_csv("Ice_cream selling data.csv")
df
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 0          -4.662263                41.842986
# 1          -4.316559                34.661120
# 2          -4.213985                39.383001
# 3          -3.949661                37.539845
# 4          -3.578554                32.284531
# 5          -3.455712                30.001138
# 6          -3.108440                22.635401
# 7          -3.081303                25.365022
# 8          -2.672461                19.226970
# 9          -2.652287                20.279679
# 10         -2.651498                13.275828
# 11         -2.288264                18.123991
# 12         -2.111870                11.218294
# 13         -1.818938                10.012868
# 14         -1.660348                12.615181
# 15         -1.326379                10.957731
# 16         -1.173123                 6.689123
# 17         -0.773330                 9.392969
# 18         -0.673753                 5.210163
# 19         -0.149635                 4.673643
# 20         -0.036156                 0.328626
# 21         -0.033895                 0.897603
# 22          0.008608                 3.165600
# 23          0.149245                 1.931416
# 24          0.688781                 2.576782
# 25          0.693599                 4.625689
# 26          0.874905                 0.789974
# 27          1.024181                 2.313806
# 28          1.240712                 1.292361
# 29          1.359813                 0.953115
# 30          1.740000                 3.782570
# 31          1.850552                 4.857988
# 32          1.999310                 8.943823
# 33          2.075101                 8.170735
# 34          2.318591                 7.412094
# 35          2.471946                10.336631
# 36          2.784836                15.996620
# 37          2.831760                12.568237
# 38          2.959932                21.342916
# 39          3.020874                20.114413
# 40          3.211366                22.839406
# 41          3.270044                16.983279
# 42          3.316073                25.142082
# 43          3.335932                26.104740
# 44          3.610778                28.912188
# 45          3.704057                17.843957
# 46          4.130868                34.530743
# 47          4.133534                27.698383
# 48          4.899032                41.514822

# %%
x = df[["Temperature (°C)"]]
y = df["Ice Cream Sales (units)"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=10)
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

print("mean_absolute_error  ",mean_absolute_error(y_test,y_pred))
print("mean_squared_error  ",mean_squared_error(y_test,y_pred))
print("r2_score" ,r2_score(y_test,y_pred))
print("coefficient  ",model.coef_)
# Out:
# mean_absolute_error   11.018169620462318
# mean_squared_error   164.50722719526814
# r2_score -0.028604108116984106
# coefficient   [-0.82696316]

# %%
sns.scatterplot(df,x=df["Temperature (°C)"],y=y)
# Out:
# <Axes: xlabel='Temperature (°C)', ylabel='Ice Cream Sales (units)'>

# %%
sns.regplot(df,x=df["Temperature (°C)"],y=y)
# Out:
# <Axes: xlabel='Temperature (°C)', ylabel='Ice Cream Sales (units)'>

# %%
x = df[["Temperature (°C)"]]
y = df["Ice Cream Sales (units)"]

x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=10)


from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=30)

x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# x_train_poly # y = ax^2 + bx + c

model = LinearRegression()
model.fit(x_train_poly,y_train)
y_pred = model.predict(x_test_poly)
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

print("mean_absolute_error  ",mean_absolute_error(y_test,y_pred))
print("mean_squared_error  ",mean_squared_error(y_test,y_pred))
print("r2_score" ,r2_score(y_test,y_pred))
print("coefficient  ",model.coef_)
# Out:
# mean_absolute_error   13.337001268054205
# mean_squared_error   1035.6239551291737
# r2_score -5.475381494612341
# coefficient   [-2.33774100e-07 -5.66886112e-08 -2.89109758e-09  3.95364966e-10
#   1.17199294e-09  2.02692688e-09  6.48805412e-09  1.04730240e-08
#   3.34536164e-08  5.04574327e-08  1.59636267e-07  2.18457909e-07
#   6.83539166e-07  7.99260652e-07  2.47810751e-06  2.18591952e-06
#   6.76243942e-06  3.11286174e-06  9.92882754e-06 -2.15268837e-06
#  -4.82125459e-06  4.85907977e-07  8.66231265e-07 -5.33791020e-08
#  -8.01467553e-08  3.10828042e-09  4.08268096e-09 -9.20151455e-11
#  -1.08930129e-10  1.08623434e-12  1.18991972e-12]

# %%
# Out:
# mean_absolute_error   3.0114923795415702
# mean_squared_error   11.186143275103136
# r2_score 0.9300570976550554
# coefficient   [ 0.         -0.80317614  1.75846989]

# %%
# x1,x2,x3
# y
# y = m1x1^2+m2x2^2+m3x3^2+m4x1x2+m5x2x3+m6x1x3+m7x1+m8x2+m9x3+m10b 10 feature
# n = no.fea
# d = no. degrer 
# [n+d]! / [n!*d!]

# 5! / 3!*2! 
# 120/12
# 10
